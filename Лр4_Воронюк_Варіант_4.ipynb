# %% [markdown]
# <a href="https://colab.research.google.com/github/Max640a/ChyselniMetody_lab/blob/main/%D0%9B%D1%804_%D0%92%D0%BE%D1%80%D0%BE%D0%BD%D1%8E%D0%BA_%D0%92%D0%B0%D1%80%D1%96%D0%B0%D0%BD%D1%82_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Був присутній на парі. Варіант 4. ФІТ 2-9

# %%
import numpy as np
numpy_version = np.__version__
numpy_version
# Out:
# '2.0.2'

# %% [markdown]
# 1.

# %%
matrix = np.random.randint(1, 6, size=(3,3))
matrix
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [2, 1, 5]])

# %% [markdown]
# 2. Обчислити визначник матриці

# %%
det = np.linalg.det(matrix)
det
# Out:
# np.float64(-10.000000000000002)

# %% [markdown]
# 3.

# %%
product = np.prod(matrix)
product
# Out:
# np.int64(3600)

# %%
prod_1 = np.prod(matrix[0])
prod_2 = np.prod(matrix[1])
prod_3 = np.prod(matrix[2])
prod_1*prod_2*prod_3
# Out:
# np.int64(3600)

# %% [markdown]
# 4.

# %%
np.sum(matrix)
# Out:
# np.int64(26)

# %% [markdown]
# 5.

# %%
np.max(matrix)
# Out:
# np.int64(5)

# %%
np.min(matrix)
# Out:
# np.int64(1)

# %% [markdown]
# 6.

# %%
np.mean(matrix)
# Out:
# np.float64(2.888888888888889)

# %% [markdown]
# 7.

# %%
sqrt_matrix= np.sqrt(matrix)

print(sqrt_matrix)
# Out:
# [[1.         1.41421356 1.73205081]
#  [1.73205081 2.         2.23606798]
#  [1.41421356 1.         2.23606798]]

# %% [markdown]
# 8.

# %%
np.sum(matrix, axis=1).reshape(-1,1)
# Out:
# array([[ 6],
#        [12],
#        [ 8]])

# %%
np.sum(matrix, axis=1)
# Out:
# array([ 6, 12,  8])

# %%
x = np.matrix([[1,2], [4,3]])
x
# Out:
# matrix([[1, 2],
#         [4, 3]])

# %%
x.sum(axis=1)
# Out:
# matrix([[3],
#         [7]])

# %% [markdown]
# 9. Створити вектор, що містить 25 елементів. Заповнити числами від 0 до 9. Відсортувати числа за спаданням.

# %%
vector = np.random.randint(0, 10, size=25)
vector
# Out:
# array([1, 4, 9, 2, 7, 5, 9, 2, 4, 0, 4, 8, 6, 8, 3, 9, 0, 2, 9, 4, 7, 9,
#        7, 5, 5])

# %%
#Сортуємо числа за спаданням
sorted_vector = np.sort(vector)[::-1]
sorted_vector
# Out:
# array([9, 9, 9, 9, 9, 8, 8, 7, 7, 7, 6, 5, 5, 5, 4, 4, 4, 4, 3, 2, 2, 2,
#        1, 0, 0])

# %% [markdown]
# 10.Знайти моду, медіану, середнє, максимальне, мінімальне значення

# %%
from scipy import stats

# %%
stats.mode(vector)
# Out:
# ModeResult(mode=np.int64(9), count=np.int64(5))

# %%
np.median(vector)
# Out:
# np.float64(5.0)

# %%
np.max(vector)
# Out:
# np.int64(9)

# %%
np.min(vector)
# Out:
# np.int64(0)

# %% [markdown]
# Лр4 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
a = np.array([
    [7, 3, -6],
    [7, 9, -9],
    [2, -4, 9],
])
b = np.array([[-1], [5], [28]])

# %%
#Матричний метод (1 спосіб)
det_a = np.linalg.det(a)
if det_a == 0:
    print("Визначник дорівнює нулю - рішень немає")
else:
  a_inv = np.linalg.inv(a)
  print(f"Обернена матриця до матриці A: \r\n {a_inv }")
  print(f"Вектор рішення: \r\n {a_inv.dot(b)}")
# Out:
# Обернена матриця до матриці A:
#  [[ 0.12931034 -0.00862069  0.07758621]
#  [-0.23275862  0.21551724  0.06034483]
#  [-0.13218391  0.09770115  0.12068966]]
# Вектор рішення:
#  [[2.]
#  [3.]
#  [4.]]

# %%
# Напиши функцію для вирішення системи матричним методом (2 спосіб)
def solve_inv_matrix(a, b, verbose=False):
    det = np.linalg.det(a)
    if verbose: print(f"Визначник матриці A: {round(det)}")
    if det == 0:
        print("Визначник дорівнює нулю - рішень немає")
        return None

    a_inv= np.linalg.inv(a)
    if verbose: print(f"Обернена матриця до матриці A: \r\n {a_inv }")
    return a_inv.dot(b)

print(f"Вектор рішення: \r\n {solve_inv_matrix(a, b)}")
# Out:
# Вектор рішення:
#  [[2.]
#  [3.]
#  [4.]]

# %%
#метод Крамера (1 спосіб)
# Метод Крамера
det_a = np.linalg.det(a)

if det_a == 0:
    print("Визначник дорівнює нулю — система не має єдиного розв’язку.")
else:
    def replace_column(matrix, column_index, new_column):
        new_matrix = np.copy(matrix)
        new_matrix[:, column_index] = new_column
        return new_matrix

    # Обчислюємо Δx, Δy, Δz
    delta_x = np.linalg.det(replace_column(a, 0, b.T))
    delta_y = np.linalg.det(replace_column(a, 1, b.T))
    delta_z = np.linalg.det(replace_column(a, 2, b.T))

    # Обчислюємо x, y, z
    print('x =', delta_x / det_a)
    print('y =', delta_y / det_a)
    print('z =', delta_z / det_a)
# Out:
# x = 1.9999999999999984
# y = 2.9999999999999982
# z = 3.9999999999999973

# %%
# Напиши функцію для вирішення системи методом Крамера
def solve_cramer(a, b, verbose=False):
    det = np.linalg.det(a)
    if verbose: print(f"Визначник матриці A: {round(det)}")
    if det == 0:
        print("Визначник дорівнює нулю - рішень немає")
        return None

    len_a = len(a)
    x = np.zeros((len_a, 1))
    for i in range(len_a):
        temp = np.copy(a)
        temp[:, [i]] = b
        x[i, 0] = np.linalg.det(temp)/det

    return x


print(f"Вектор рішення: \r\n {solve_cramer(a, b)}")
# Out:
# Вектор рішення:
#  [[2.]
#  [3.]
#  [4.]]

# %%
x = np.linalg.solve(a, b)

print(x)
# Out:
# [[2.]
#  [3.]
#  [4.]]
